# %% [markdown]
# <a href="https://colab.research.google.com/github/chuanjiewu144/multivariate-time-series-forecast/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook formulates a multi-variable forecasting problem to predict the next 24 hours of energy demand in Spain.
#
# By comparing the forecasting performance of using several different model types, each model uses the same final two DNN layers with dropout. One of 128 units, and the final layer of 24 (the output horizon). Each of the models unique layers are:
# 1. A three layer DNN (one layer plus the common bottom two layers)
# 2. A CNN with two layers of 1D convolutions with max pooling.
# 3. A LSTM with two LSTM layers.
# 4. A CNN stacked LSTM with layers from models 2 and 3 feeding into the common DNN layer.
# 5. A CNN stacked LSTM with a skip connection to the common DNN layer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

# %%
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import chardet
file='/content/energy_dataset.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
def load_data(col=None, path= '/content/energy_dataset3.csv', verbose=False):
    df = pd.read_csv(path, sep=';')
    if col is not None:
        df = df[col]
    if verbose:
        print(df.head())
    return df

print("Multivariate Sample")
multivar_df = load_data(['time','total load actual', 'price actual'], verbose=True)
# Out:
# Multivariate Sample
#                         time  total load actual  price actual
# 0  2015-01-01 00:00:00+01:00            25385.0         65.41
# 1  2015-01-01 01:00:00+01:00            24382.0         64.92
# 2  2015-01-01 02:00:00+01:00            22734.0         64.48
# 3  2015-01-01 03:00:00+01:00            21286.0         59.32
# 4  2015-01-01 04:00:00+01:00            20264.0         56.04

# %%
df = load_data(col=["total load forecast","total load actual"])

#fill nans with linear interpolation because this is how we will fill when using the data in the models.
df_filled = df.interpolate("linear")
mm = MinMaxScaler()
df_scaled = mm.fit_transform(df_filled)

df_prep = pd.DataFrame(df_scaled, columns=df.columns)
y_true = df_prep["total load actual"]
y_pred_forecast = df_prep["total load forecast"]

### persistence 1 day
#shift series by 24 hours
# realign y_true to have the same length and time samples
y_preds_persistance_1_day = y_true.shift(24).dropna()
persistence_1_day_mae = tf.keras.losses.MAE(y_true[y_preds_persistance_1_day.index], y_preds_persistance_1_day).numpy()
persistence_1_day_mape = tf.keras.losses.MAPE(np.maximum(y_true[y_preds_persistance_1_day.index], 1e-5), np.maximum(y_preds_persistance_1_day, 1e-5)).numpy()


### persistence 3 day average
#shift by 1, 2, 3 days. Realign to have same lengths. Average days and calcualte MAE.

shift_dfs = list()
for i in range(1, 4):
    shift_dfs.append(pd.Series(y_true.shift(24 * i), name=f"d{i}"))

y_persistance_3d = pd.concat(shift_dfs, axis=1).dropna()
y_persistance_3d["avg"] = (y_persistance_3d["d1"] + y_persistance_3d["d2"] + y_persistance_3d["d3"])/3
d3_idx = y_persistance_3d.index
persistence_3day_avg_mae = tf.keras.losses.MAE(y_true[d3_idx], y_persistance_3d['avg']).numpy()
persistence_3day_avg_mape = tf.keras.losses.MAPE(np.maximum(y_true[d3_idx], 1e-5), np.maximum(y_persistance_3d['avg'], 1e-5)).numpy()

ref_error = pd.DataFrame({
    "Method": ["TSO Forecast", "Persistence 1 Day", "Persitence 3 Day Avg"],
    "MAE": [tf.keras.losses.MAE(y_true, y_pred_forecast).numpy(),
            persistence_1_day_mae,
            persistence_3day_avg_mae],
    "MAPE":[tf.keras.losses.MAPE(np.maximum(y_true, 1e-5), np.maximum(y_pred_forecast, 1e-5)).numpy(),
            persistence_1_day_mape,
            persistence_3day_avg_mape]}, 
    index=[i for i in range(3)])

print("\nSummary of Baseline Errors")
print(ref_error)
print(f"\nAverage error in MW for TSO Forecast {round(df['total load forecast'].mean()*ref_error.iloc[0,1], 2)}")
# Out:
# Summary of Baseline Errors
#                  Method       MAE       MAPE
# 0          TSO Forecast  0.015456   5.472781
# 1     Persistence 1 Day  0.106903  65.951647
# 2  Persitence 3 Day Avg  0.115176  84.151898
#
# Average error in MW for TSO Forecast 443.76

# %% [markdown]
# Preparing the Data
# We will use tf.datasets to prepare the data. The general strategy is to clean, scale, and split the data before creating the tf.dataset object. These steps can alternatively be done within the tf.dataset itself.
#
# Cleaning data: Fill any missing values with a linear interpolation of the value. Same as done in the persistence dataset.
#
# Scaling data: In all cases the data is min max scaled.
#
# Features: As part of this simple analysis of models two feature sets are prepared. The univariate that contains energy consumption data only. The multivariate that contains energy consumption, price, day of the week, and month of the year.
#
# Splitting data: One year of test data (8769 hourly samples) is put aside to evaluate all the models. The train and validation sets are created with a 65/35 split, resulting in 9207 validation samples - just over one year.

# %%
def clean_data(series):
    
    series_filled = series.interpolate(method='linear')
        
    return series_filled
        
    
def min_max_scale(dataframe):
    
    mm = MinMaxScaler()
    return mm.fit_transform(dataframe)

def make_time_features(series):
    
    #convert series to datetimes
    times = series.apply(lambda x: x.split('+')[0])
    datetimes = pd.DatetimeIndex(times)
    
    hours = datetimes.hour.values
    day = datetimes.dayofweek.values
    months = datetimes.month.values
    
    hour = pd.Series(hours, name='hours')
    dayofw = pd.Series(day, name='dayofw')
    month = pd.Series(months, name='months')
    
    return hour, dayofw, month

hour, day, month = make_time_features(multivar_df.time)
print("Hours")
print(hour.head())
print("Day of Week")
print(day.head())
print("Months")
print(month.head())
# Out:
# Hours
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: hours, dtype: int64
# Day of Week
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: dayofw, dtype: int64
# Months
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: months, dtype: int64

# %%
def split_data(series, train_fraq, test_len=8760):
    """Splits input series into train, val and test.
    
        Default to 1 year of test data.
    """
    #slice the last year of data for testing 1 year has 8760 hours
    test_slice = len(series)-test_len

    test_data = series[test_slice:]
    train_val_data = series[:test_slice]

    #make train and validation from the remaining
    train_size = int(len(train_val_data) * train_fraq)
    
    train_data = train_val_data[:train_size]
    val_data = train_val_data[train_size:]
    
    return train_data, val_data, test_data

# %%
multivar_df = clean_data(multivar_df)

#add hour and month features
hours, day, months = make_time_features(multivar_df.time)
multivar_df = pd.concat([multivar_df.drop(['time'], axis=1), hours, day, months], axis=1)

#scale
multivar_df = min_max_scale(multivar_df)
train_multi, val_multi, test_multi = split_data(multivar_df, train_fraq=0.65, test_len=8760)
print("Multivarate Datasets")
print(f"Train Data Shape: {train_multi.shape}")
print(f"Val Data Shape: {val_multi.shape}")
print(f"Test Data Shape: {test_multi.shape}")
print(f"Nulls In Train {np.any(np.isnan(train_multi))}")
print(f"Nulls In Validation {np.any(np.isnan(val_multi))}")
print(f"Nulls In Test {np.any(np.isnan(test_multi))}")
# Out:
# Multivarate Datasets
# Train Data Shape: (17097, 5)
# Val Data Shape: (9207, 5)
# Test Data Shape: (8760, 5)
# Nulls In Train False
# Nulls In Validation False
# Nulls In Test False

# %% [markdown]
# Windowing the Dataset
# Use tf.dataset to create a window dataset. This is a vector of past timesteps (n_steps) that is used to predict on a target vector of future steps (n_horizon). The example below shows the output for n_steps = 72 and n_horizon = 24 and the 5 features. So we use the last 3 days (72 hours) to predict the next day (following 24 hours).
#
# The resulting shape for X will be (batch size, n_steps, features) and Y will be (batch size, n_horizon, features).

# %%
def window_dataset(data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=False, expand_dims=False):
  

    #create a window with n steps back plus the size of the prediction length
    window = n_steps + n_horizon
    
    #expand dimensions to 3D to fit with LSTM inputs
    #creat the inital tensor dataset
    if expand_dims:
        ds = tf.expand_dims(data, axis=-1)
        ds = tf.data.Dataset.from_tensor_slices(ds)
    else:
        ds = tf.data.Dataset.from_tensor_slices(data)
       #create the window function shifting the data by the prediction length
    ds = ds.window(window, shift=n_horizon, drop_remainder=True)
    
    #flatten the dataset and batch into the window size
    ds = ds.flat_map(lambda x : x.batch(window))
    ds = ds.shuffle(shuffle_buffer)    
    
    #create the supervised learning problem x and y and batch
    if multi_var:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:, :1]))
    else:
        ds = ds.map(lambda x : (x[:-n_horizon], x[-n_horizon:]))
    
    ds = ds.batch(batch_size).prefetch(1)
    return ds

tf.random.set_seed(42)

n_steps = 72
n_horizon = 24
batch_size = 1
shuffle_buffer = 100


ds = window_dataset(train_multi, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=True)


print('Example sample shapes')
for idx,(x,y) in enumerate(ds):
    print("x = ", x.numpy().shape)
    print("y = ", y.numpy().shape)
    break
# Out:
# Example sample shapes
# x =  (1, 72, 5)
# y =  (1, 24, 1)

# %%
def build_dataset(train_fraq=0.65, 
                  n_steps=24*30, 
                  n_horizon=24, 
                  batch_size=256, 
                  shuffle_buffer=500, 
                  expand_dims=False, 
                  multi_var=False):
   
    
    tf.random.set_seed(23)
    
    if multi_var:
        data = load_data(col=['time', 'total load actual', 'price actual'])
        hours, day, months = make_time_features(data.time)
        data = pd.concat([data.drop(['time'], axis=1), hours, day, months], axis=1)

    else:
        data = load_data(col=['total load actual'])
        
    data = clean_data(data)
    
    if multi_var:
        mm = MinMaxScaler()
        data = mm.fit_transform(data)
    
    train_data, val_data, test_data = split_data(data, train_fraq=train_fraq, test_len=8760)
    
    train_ds = window_dataset(train_data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    val_ds = window_dataset(val_data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)
    test_ds = window_dataset(test_data, n_steps, n_horizon, batch_size, shuffle_buffer, multi_var=multi_var, expand_dims=expand_dims)

    print(f"Prediction lookback (n_steps): {n_steps}")
    print(f"Prediction horizon (n_horizon): {n_horizon}")
    print(f"Batch Size: {batch_size}")
    print("Datasets:")
    print(train_ds.element_spec)
    
    return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = build_dataset(multi_var=True)
# Out:
# Prediction lookback (n_steps): 720
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))

# %%
def get_params(multivar=False):
    lr = 3e-4
    n_steps=24*30
    n_horizon=24
    if multivar:
        n_features=5
    else:
        n_features=1
        
    return n_steps, n_horizon, n_features, lr

model_configs = dict()
def cfg_model_run(model, history, test_ds):
    return {"model": model, "history" : history, "test_ds": test_ds}


def run_model(model_name, model_func, model_configs, epochs):
    
    n_steps, n_horizon, n_features, lr = get_params(multivar=True)
    train_ds, val_ds, test_ds = build_dataset(n_steps=n_steps, n_horizon=n_horizon, multi_var=True)
    model = model_func(n_steps, n_horizon, n_features, lr=lr)

    model_hist = model.fit(train_ds, validation_data=val_ds, epochs=epochs)

    model_configs[model_name] = cfg_model_run(model, model_hist, test_ds)
    return test_ds

# %% [markdown]
# DNN: A single 128 unit layer plus the common 128 and 24 unit layyers with dropout.

# %%
def dnn_model(n_steps, n_horizon, n_features, lr):
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Flatten(input_shape=(n_steps, n_features)),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='dnn')
    
    loss=tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(lr=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae'])
    
    return model


dnn = dnn_model(*get_params(multivar=True))
dnn.summary()
# Out:
# Model: "dnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 3600)              0
#
#  dense (Dense)               (None, 128)               460928
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 480,536
# Trainable params: 480,536
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# CNN: Two Conv 1D layers with 64 filters each, and kernel sizes of 6 and 3 respectively. After each Conv1D layer a maxpooling1D layer with size of 2.

# %%
def cnn_model(n_steps, n_horizon, n_features, lr=3e-4):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="CNN")
    loss= tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(lr=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae'])
    
    return model

cnn = cnn_model(*get_params(multivar=True))
cnn.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 715, 64)           1984
#
#  max_pooling1d (MaxPooling1D  (None, 357, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 355, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 177, 64)          0
#  1D)
#
#  flatten (Flatten)           (None, 11328)             0
#
#  dropout (Dropout)           (None, 11328)             0
#
#  dense (Dense)               (None, 128)               1450112
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 1,467,544
# Trainable params: 1,467,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# LSTM: Two LSTM layers with 72 and 48 units each.

# %%
def lstm_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.LSTM(72, activation='relu', input_shape=(n_steps, n_features), return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name='lstm')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(lr=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae'])
    
    return model

lstm = lstm_model(*get_params(multivar=True))
lstm.summary()
# Out:
# Model: "lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 720, 72)           22464
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 55,064
# Trainable params: 55,064
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN and LSTM Stacked: Using the same layers from the CNN and LSTM model, stack the CNN as input to the pair of LSTMs.

# %%
def lstm_cnn_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
    model = tf.keras.models.Sequential([
        tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu', input_shape=(n_steps,n_features)),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu'),
        tf.keras.layers.MaxPooling1D(2),
        tf.keras.layers.LSTM(72, activation='relu', return_sequences=True),
        tf.keras.layers.LSTM(48, activation='relu', return_sequences=False),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(128),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(n_horizon)
    ], name="lstm_cnn")
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(lr=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae'])
    
    return model

lstm_cnn = lstm_cnn_model(*get_params(multivar=True))
lstm_cnn.summary()
# Out:
# Model: "lstm_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 715, 64)           1984
#
#  max_pooling1d (MaxPooling1D  (None, 357, 64)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 355, 64)           12352
#
#  max_pooling1d_1 (MaxPooling  (None, 177, 64)          0
#  1D)
#
#  lstm (LSTM)                 (None, 177, 72)           39456
#
#  lstm_1 (LSTM)               (None, 48)                23232
#
#  flatten (Flatten)           (None, 48)                0
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 128)               6272
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 24)                3096
#
# =================================================================
# Total params: 86,392
# Trainable params: 86,392
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN and LSTM with a skip connection: The same CNN and LSTM layers as the previous models this time with a skip connection direct to the common DNN layer.

# %%
def lstm_cnn_skip_model(n_steps, n_horizon, n_features, lr):
    
    tf.keras.backend.clear_session()
    
   
    inputs = tf.keras.layers.Input(shape=(n_steps,n_features), name='main')
    
    conv1 = tf.keras.layers.Conv1D(64, kernel_size=6, activation='relu')(inputs)
    max_pool_1 = tf.keras.layers.MaxPooling1D(2)(conv1)
    conv2 = tf.keras.layers.Conv1D(64, kernel_size=3, activation='relu')(max_pool_1)
    max_pool_2 = tf.keras.layers.MaxPooling1D(2)(conv2)
    lstm_1 = tf.keras.layers.LSTM(72, activation='relu', return_sequences=True)(max_pool_2)
    lstm_2 = tf.keras.layers.LSTM(48, activation='relu', return_sequences=False)(lstm_1)
    flatten = tf.keras.layers.Flatten()(lstm_2)
    
    skip_flatten = tf.keras.layers.Flatten()(inputs)
    concat = tf.keras.layers.Concatenate(axis=-1)([flatten, skip_flatten])
    drop_1 = tf.keras.layers.Dropout(0.3)(concat)
    dense_1 = tf.keras.layers.Dense(128, activation='relu')(drop_1)
    drop_2 = tf.keras.layers.Dropout(0.3)(dense_1)
    output = tf.keras.layers.Dense(n_horizon)(drop_2)
    
    model = tf.keras.Model(inputs=inputs, outputs=output, name='lstm_skip')
    
    loss = tf.keras.losses.Huber()
    optimizer = tf.keras.optimizers.Adam(lr=lr)
    
    model.compile(loss=loss, optimizer='adam', metrics=['mae'])
    
    return model
  
lstm_skip = lstm_cnn_skip_model(*get_params(multivar=True))
lstm_skip.summary()
# Out:
# Model: "lstm_skip"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  main (InputLayer)              [(None, 720, 5)]     0           []
#
#  conv1d (Conv1D)                (None, 715, 64)      1984        ['main[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 357, 64)      0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 355, 64)      12352       ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 177, 64)     0           ['conv1d_1[0][0]']
#
#  lstm (LSTM)                    (None, 177, 72)      39456       ['max_pooling1d_1[0][0]']
#
#  lstm_1 (LSTM)                  (None, 48)           23232       ['lstm[0][0]']
#
#  flatten (Flatten)              (None, 48)           0           ['lstm_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 3600)         0           ['main[0][0]']
#
#  concatenate (Concatenate)      (None, 3648)         0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dropout (Dropout)              (None, 3648)         0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 128)          467072      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 24)           3096        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 547,192
# Trainable params: 547,192
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(lstm_skip, show_shapes=True)

# %% [markdown]
# Train Models: Run each model for 150 epochs.

# %%
model_configs=dict()
run_model("dnn", dnn_model, model_configs, epochs=150)
run_model("cnn", cnn_model, model_configs, epochs=150)
run_model("lstm", lstm_model, model_configs, epochs=150)
run_model("lstm_cnn", lstm_cnn_model, model_configs, epochs=150)
run_model("lstm_skip", lstm_cnn_skip_model, model_configs, epochs=150)
# Out:
# Prediction lookback (n_steps): 720
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/150
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 4s 444ms/step - loss: 0.3155 - mae: 0.6676 - val_loss: 0.1295 - val_mae: 0.4319
# Epoch 2/150
# 3/3 [==============================] - 1s 134ms/step - loss: 0.1125 - mae: 0.4143 - val_loss: 0.1000 - val_mae: 0.3806
# Epoch 3/150
# 3/3 [==============================] - 1s 136ms/step - loss: 0.0898 - mae: 0.3546 - val_loss: 0.0857 - val_mae: 0.3283
# Epoch 4/150
# 3/3 [==============================] - 1s 149ms/step - loss: 0.0781 - mae: 0.3243 - val_loss: 0.0750 - val_mae: 0.3074
# Epoch 5/150
# 3/3 [==============================] - 1s 157ms/step - loss: 0.0656 - mae: 0.2931 - val_loss: 0.0623 - val_mae: 0.2794
# Epoch 6/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0588 - mae: 0.2765 - val_loss: 0.0577 - val_mae: 0.2700
# Epoch 7/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0506 - mae: 0.2540 - val_loss: 0.0499 - val_mae: 0.2522
# Epoch 8/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0438 - mae: 0.2353 - val_loss: 0.0472 - val_mae: 0.2456
# Epoch 9/150
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0379 - mae: 0.2176 - val_loss: 0.0411 - val_mae: 0.2300
# Epoch 10/150
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0360 - mae: 0.2114 - val_loss: 0.0439 - val_mae: 0.2386
# Epoch 11/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0340 - mae: 0.2058 - val_loss: 0.0389 - val_mae: 0.2300
# Epoch 12/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0311 - mae: 0.1961 - val_loss: 0.0400 - val_mae: 0.2274
# Epoch 13/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0284 - mae: 0.1875 - val_loss: 0.0389 - val_mae: 0.2264
# Epoch 14/150
# 3/3 [==============================] - 1s 149ms/step - loss: 0.0266 - mae: 0.1808 - val_loss: 0.0387 - val_mae: 0.2312
# Epoch 15/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0265 - mae: 0.1807 - val_loss: 0.0373 - val_mae: 0.2223
# Epoch 16/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0242 - mae: 0.1723 - val_loss: 0.0380 - val_mae: 0.2255
# Epoch 17/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0241 - mae: 0.1721 - val_loss: 0.0399 - val_mae: 0.2335
# Epoch 18/150
# 3/3 [==============================] - 1s 131ms/step - loss: 0.0240 - mae: 0.1708 - val_loss: 0.0364 - val_mae: 0.2223
# Epoch 19/150
# 3/3 [==============================] - 1s 140ms/step - loss: 0.0227 - mae: 0.1659 - val_loss: 0.0370 - val_mae: 0.2240
# Epoch 20/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0224 - mae: 0.1663 - val_loss: 0.0386 - val_mae: 0.2309
# Epoch 21/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0199 - mae: 0.1562 - val_loss: 0.0388 - val_mae: 0.2275
# Epoch 22/150
# 3/3 [==============================] - 1s 133ms/step - loss: 0.0200 - mae: 0.1560 - val_loss: 0.0380 - val_mae: 0.2279
# Epoch 23/150
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0195 - mae: 0.1537 - val_loss: 0.0384 - val_mae: 0.2279
# Epoch 24/150
# 3/3 [==============================] - 1s 142ms/step - loss: 0.0188 - mae: 0.1503 - val_loss: 0.0377 - val_mae: 0.2260
# Epoch 25/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0200 - mae: 0.1562 - val_loss: 0.0391 - val_mae: 0.2307
# Epoch 26/150
# 3/3 [==============================] - 1s 132ms/step - loss: 0.0197 - mae: 0.1551 - val_loss: 0.0401 - val_mae: 0.2318
# Epoch 27/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0185 - mae: 0.1506 - val_loss: 0.0386 - val_mae: 0.2326
# Epoch 28/150
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0181 - mae: 0.1488 - val_loss: 0.0396 - val_mae: 0.2357
# Epoch 29/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0183 - mae: 0.1491 - val_loss: 0.0384 - val_mae: 0.2286
# Epoch 30/150
# 3/3 [==============================] - 1s 153ms/step - loss: 0.0181 - mae: 0.1483 - val_loss: 0.0380 - val_mae: 0.2292
# Epoch 31/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0156 - mae: 0.1375 - val_loss: 0.0396 - val_mae: 0.2316
# Epoch 32/150
# 3/3 [==============================] - 1s 145ms/step - loss: 0.0172 - mae: 0.1454 - val_loss: 0.0383 - val_mae: 0.2310
# Epoch 33/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0160 - mae: 0.1395 - val_loss: 0.0380 - val_mae: 0.2296
# Epoch 34/150
# 3/3 [==============================] - 1s 149ms/step - loss: 0.0149 - mae: 0.1341 - val_loss: 0.0382 - val_mae: 0.2295
# Epoch 35/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0153 - mae: 0.1352 - val_loss: 0.0381 - val_mae: 0.2309
# Epoch 36/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0149 - mae: 0.1335 - val_loss: 0.0385 - val_mae: 0.2328
# Epoch 37/150
# 3/3 [==============================] - 1s 141ms/step - loss: 0.0146 - mae: 0.1327 - val_loss: 0.0385 - val_mae: 0.2289
# Epoch 38/150
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0151 - mae: 0.1350 - val_loss: 0.0379 - val_mae: 0.2297
# Epoch 39/150
# 3/3 [==============================] - 1s 142ms/step - loss: 0.0146 - mae: 0.1325 - val_loss: 0.0398 - val_mae: 0.2380
# Epoch 40/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0140 - mae: 0.1298 - val_loss: 0.0378 - val_mae: 0.2288
# Epoch 41/150
# 3/3 [==============================] - 1s 134ms/step - loss: 0.0136 - mae: 0.1285 - val_loss: 0.0377 - val_mae: 0.2279
# Epoch 42/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0141 - mae: 0.1313 - val_loss: 0.0386 - val_mae: 0.2338
# Epoch 43/150
# 3/3 [==============================] - 1s 132ms/step - loss: 0.0128 - mae: 0.1245 - val_loss: 0.0401 - val_mae: 0.2378
# Epoch 44/150
# 3/3 [==============================] - 1s 146ms/step - loss: 0.0131 - mae: 0.1265 - val_loss: 0.0383 - val_mae: 0.2332
# Epoch 45/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0127 - mae: 0.1242 - val_loss: 0.0383 - val_mae: 0.2313
# Epoch 46/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0133 - mae: 0.1261 - val_loss: 0.0379 - val_mae: 0.2293
# Epoch 47/150
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0128 - mae: 0.1243 - val_loss: 0.0393 - val_mae: 0.2367
# Epoch 48/150
# 3/3 [==============================] - 1s 131ms/step - loss: 0.0119 - mae: 0.1204 - val_loss: 0.0405 - val_mae: 0.2397
# Epoch 49/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0123 - mae: 0.1222 - val_loss: 0.0376 - val_mae: 0.2298
# Epoch 50/150
# 3/3 [==============================] - 1s 182ms/step - loss: 0.0115 - mae: 0.1179 - val_loss: 0.0383 - val_mae: 0.2320
# Epoch 51/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0108 - mae: 0.1141 - val_loss: 0.0392 - val_mae: 0.2346
# Epoch 52/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0115 - mae: 0.1179 - val_loss: 0.0397 - val_mae: 0.2379
# Epoch 53/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0108 - mae: 0.1147 - val_loss: 0.0391 - val_mae: 0.2356
# Epoch 54/150
# 3/3 [==============================] - 1s 175ms/step - loss: 0.0105 - mae: 0.1124 - val_loss: 0.0387 - val_mae: 0.2331
# Epoch 55/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0106 - mae: 0.1144 - val_loss: 0.0413 - val_mae: 0.2433
# Epoch 56/150
# 3/3 [==============================] - 1s 165ms/step - loss: 0.0101 - mae: 0.1104 - val_loss: 0.0388 - val_mae: 0.2344
# Epoch 57/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0097 - mae: 0.1088 - val_loss: 0.0391 - val_mae: 0.2358
# Epoch 58/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0096 - mae: 0.1078 - val_loss: 0.0401 - val_mae: 0.2391
# Epoch 59/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0100 - mae: 0.1098 - val_loss: 0.0392 - val_mae: 0.2363
# Epoch 60/150
# 3/3 [==============================] - 1s 144ms/step - loss: 0.0097 - mae: 0.1089 - val_loss: 0.0403 - val_mae: 0.2399
# Epoch 61/150
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0095 - mae: 0.1069 - val_loss: 0.0401 - val_mae: 0.2387
# Epoch 62/150
# 3/3 [==============================] - 1s 163ms/step - loss: 0.0098 - mae: 0.1092 - val_loss: 0.0405 - val_mae: 0.2408
# Epoch 63/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0096 - mae: 0.1076 - val_loss: 0.0396 - val_mae: 0.2372
# Epoch 64/150
# 3/3 [==============================] - 1s 187ms/step - loss: 0.0100 - mae: 0.1095 - val_loss: 0.0404 - val_mae: 0.2400
# Epoch 65/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0094 - mae: 0.1073 - val_loss: 0.0422 - val_mae: 0.2467
# Epoch 66/150
# 3/3 [==============================] - 1s 144ms/step - loss: 0.0096 - mae: 0.1071 - val_loss: 0.0405 - val_mae: 0.2406
# Epoch 67/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0092 - mae: 0.1057 - val_loss: 0.0396 - val_mae: 0.2371
# Epoch 68/150
# 3/3 [==============================] - 1s 132ms/step - loss: 0.0094 - mae: 0.1076 - val_loss: 0.0431 - val_mae: 0.2498
# Epoch 69/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0092 - mae: 0.1053 - val_loss: 0.0404 - val_mae: 0.2398
# Epoch 70/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0097 - mae: 0.1088 - val_loss: 0.0398 - val_mae: 0.2378
# Epoch 71/150
# 3/3 [==============================] - 1s 136ms/step - loss: 0.0089 - mae: 0.1045 - val_loss: 0.0426 - val_mae: 0.2482
# Epoch 72/150
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0092 - mae: 0.1065 - val_loss: 0.0416 - val_mae: 0.2441
# Epoch 73/150
# 3/3 [==============================] - 1s 134ms/step - loss: 0.0096 - mae: 0.1080 - val_loss: 0.0397 - val_mae: 0.2374
# Epoch 74/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0095 - mae: 0.1081 - val_loss: 0.0432 - val_mae: 0.2498
# Epoch 75/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0095 - mae: 0.1075 - val_loss: 0.0401 - val_mae: 0.2384
# Epoch 76/150
# 3/3 [==============================] - 1s 137ms/step - loss: 0.0097 - mae: 0.1089 - val_loss: 0.0420 - val_mae: 0.2457
# Epoch 77/150
# 3/3 [==============================] - 1s 133ms/step - loss: 0.0096 - mae: 0.1078 - val_loss: 0.0399 - val_mae: 0.2385
# Epoch 78/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0102 - mae: 0.1121 - val_loss: 0.0419 - val_mae: 0.2460
# Epoch 79/150
# 3/3 [==============================] - 1s 180ms/step - loss: 0.0094 - mae: 0.1059 - val_loss: 0.0400 - val_mae: 0.2383
# Epoch 80/150
# 3/3 [==============================] - 1s 167ms/step - loss: 0.0098 - mae: 0.1090 - val_loss: 0.0403 - val_mae: 0.2388
# Epoch 81/150
# 3/3 [==============================] - 1s 144ms/step - loss: 0.0094 - mae: 0.1071 - val_loss: 0.0417 - val_mae: 0.2438
# Epoch 82/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0097 - mae: 0.1087 - val_loss: 0.0393 - val_mae: 0.2348
# Epoch 83/150
# 3/3 [==============================] - 1s 146ms/step - loss: 0.0099 - mae: 0.1098 - val_loss: 0.0389 - val_mae: 0.2333
# Epoch 84/150
# 3/3 [==============================] - 1s 149ms/step - loss: 0.0098 - mae: 0.1095 - val_loss: 0.0390 - val_mae: 0.2337
# Epoch 85/150
# 3/3 [==============================] - 1s 149ms/step - loss: 0.0100 - mae: 0.1101 - val_loss: 0.0390 - val_mae: 0.2341
# Epoch 86/150
# 3/3 [==============================] - 1s 138ms/step - loss: 0.0099 - mae: 0.1102 - val_loss: 0.0390 - val_mae: 0.2347
# Epoch 87/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0100 - mae: 0.1105 - val_loss: 0.0392 - val_mae: 0.2350
# Epoch 88/150
# 3/3 [==============================] - 1s 134ms/step - loss: 0.0102 - mae: 0.1120 - val_loss: 0.0394 - val_mae: 0.2355
# Epoch 89/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0095 - mae: 0.1081 - val_loss: 0.0395 - val_mae: 0.2365
# Epoch 90/150
# 3/3 [==============================] - 1s 131ms/step - loss: 0.0099 - mae: 0.1102 - val_loss: 0.0397 - val_mae: 0.2365
# Epoch 91/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0102 - mae: 0.1113 - val_loss: 0.0397 - val_mae: 0.2368
# Epoch 92/150
# 3/3 [==============================] - 1s 145ms/step - loss: 0.0102 - mae: 0.1118 - val_loss: 0.0402 - val_mae: 0.2393
# Epoch 93/150
# 3/3 [==============================] - 1s 140ms/step - loss: 0.0103 - mae: 0.1114 - val_loss: 0.0395 - val_mae: 0.2369
# Epoch 94/150
# 3/3 [==============================] - 1s 131ms/step - loss: 0.0098 - mae: 0.1101 - val_loss: 0.0420 - val_mae: 0.2470
# Epoch 95/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0103 - mae: 0.1123 - val_loss: 0.0397 - val_mae: 0.2373
# Epoch 96/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0104 - mae: 0.1127 - val_loss: 0.0424 - val_mae: 0.2485
# Epoch 97/150
# 3/3 [==============================] - 1s 142ms/step - loss: 0.0102 - mae: 0.1112 - val_loss: 0.0398 - val_mae: 0.2382
# Epoch 98/150
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0102 - mae: 0.1120 - val_loss: 0.0398 - val_mae: 0.2380
# Epoch 99/150
# 3/3 [==============================] - 1s 172ms/step - loss: 0.0103 - mae: 0.1109 - val_loss: 0.0436 - val_mae: 0.2528
# Epoch 100/150
# 3/3 [==============================] - 1s 136ms/step - loss: 0.0103 - mae: 0.1123 - val_loss: 0.0399 - val_mae: 0.2391
# Epoch 101/150
# 3/3 [==============================] - 1s 129ms/step - loss: 0.0098 - mae: 0.1097 - val_loss: 0.0415 - val_mae: 0.2455
# Epoch 102/150
# 3/3 [==============================] - 1s 176ms/step - loss: 0.0095 - mae: 0.1069 - val_loss: 0.0401 - val_mae: 0.2400
# Epoch 103/150
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0096 - mae: 0.1081 - val_loss: 0.0411 - val_mae: 0.2437
# Epoch 104/150
# 3/3 [==============================] - 1s 140ms/step - loss: 0.0097 - mae: 0.1090 - val_loss: 0.0403 - val_mae: 0.2405
# Epoch 105/150
# 3/3 [==============================] - 1s 146ms/step - loss: 0.0091 - mae: 0.1052 - val_loss: 0.0407 - val_mae: 0.2423
# Epoch 106/150
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0093 - mae: 0.1065 - val_loss: 0.0414 - val_mae: 0.2448
# Epoch 107/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0095 - mae: 0.1066 - val_loss: 0.0403 - val_mae: 0.2406
# Epoch 108/150
# 3/3 [==============================] - 1s 140ms/step - loss: 0.0096 - mae: 0.1075 - val_loss: 0.0409 - val_mae: 0.2431
# Epoch 109/150
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0096 - mae: 0.1078 - val_loss: 0.0402 - val_mae: 0.2403
# Epoch 110/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0096 - mae: 0.1074 - val_loss: 0.0420 - val_mae: 0.2472
# Epoch 111/150
# 3/3 [==============================] - 1s 159ms/step - loss: 0.0094 - mae: 0.1069 - val_loss: 0.0401 - val_mae: 0.2400
# Epoch 112/150
# 3/3 [==============================] - 1s 143ms/step - loss: 0.0093 - mae: 0.1068 - val_loss: 0.0414 - val_mae: 0.2447
# Epoch 113/150
# 3/3 [==============================] - 1s 179ms/step - loss: 0.0099 - mae: 0.1090 - val_loss: 0.0410 - val_mae: 0.2435
# Epoch 114/150
# 3/3 [==============================] - 1s 146ms/step - loss: 0.0094 - mae: 0.1061 - val_loss: 0.0409 - val_mae: 0.2429
# Epoch 115/150
# 3/3 [==============================] - 1s 153ms/step - loss: 0.0095 - mae: 0.1070 - val_loss: 0.0417 - val_mae: 0.2463
# Epoch 116/150
# 3/3 [==============================] - 1s 161ms/step - loss: 0.0094 - mae: 0.1066 - val_loss: 0.0407 - val_mae: 0.2423
# Epoch 117/150
# 3/3 [==============================] - 1s 132ms/step - loss: 0.0097 - mae: 0.1085 - val_loss: 0.0406 - val_mae: 0.2420
# Epoch 118/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0092 - mae: 0.1048 - val_loss: 0.0409 - val_mae: 0.2433
# Epoch 119/150
# 3/3 [==============================] - 1s 166ms/step - loss: 0.0091 - mae: 0.1053 - val_loss: 0.0421 - val_mae: 0.2475
# Epoch 120/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0093 - mae: 0.1054 - val_loss: 0.0403 - val_mae: 0.2407
# Epoch 121/150
# 3/3 [==============================] - 1s 188ms/step - loss: 0.0093 - mae: 0.1057 - val_loss: 0.0408 - val_mae: 0.2426
# Epoch 122/150
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0090 - mae: 0.1036 - val_loss: 0.0443 - val_mae: 0.2550
# Epoch 123/150
# 3/3 [==============================] - 1s 191ms/step - loss: 0.0092 - mae: 0.1058 - val_loss: 0.0399 - val_mae: 0.2390
# Epoch 124/150
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0095 - mae: 0.1071 - val_loss: 0.0410 - val_mae: 0.2433
# Epoch 125/150
# 3/3 [==============================] - 1s 150ms/step - loss: 0.0088 - mae: 0.1029 - val_loss: 0.0429 - val_mae: 0.2500
# Epoch 126/150
# 3/3 [==============================] - 1s 183ms/step - loss: 0.0093 - mae: 0.1056 - val_loss: 0.0427 - val_mae: 0.2494
# Epoch 127/150
# 3/3 [==============================] - 1s 144ms/step - loss: 0.0093 - mae: 0.1056 - val_loss: 0.0400 - val_mae: 0.2395
# Epoch 128/150
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0093 - mae: 0.1061 - val_loss: 0.0400 - val_mae: 0.2396
# Epoch 129/150
# 3/3 [==============================] - 1s 142ms/step - loss: 0.0097 - mae: 0.1088 - val_loss: 0.0430 - val_mae: 0.2504
# Epoch 130/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0087 - mae: 0.1025 - val_loss: 0.0400 - val_mae: 0.2395
# Epoch 131/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0090 - mae: 0.1040 - val_loss: 0.0416 - val_mae: 0.2456
# Epoch 132/150
# 3/3 [==============================] - 1s 156ms/step - loss: 0.0094 - mae: 0.1071 - val_loss: 0.0428 - val_mae: 0.2496
# Epoch 133/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0090 - mae: 0.1035 - val_loss: 0.0413 - val_mae: 0.2441
# Epoch 134/150
# 3/3 [==============================] - 1s 164ms/step - loss: 0.0089 - mae: 0.1038 - val_loss: 0.0455 - val_mae: 0.2585
# Epoch 135/150
# 3/3 [==============================] - 1s 178ms/step - loss: 0.0098 - mae: 0.1091 - val_loss: 0.0393 - val_mae: 0.2363
# Epoch 136/150
# 3/3 [==============================] - 1s 146ms/step - loss: 0.0096 - mae: 0.1082 - val_loss: 0.0434 - val_mae: 0.2516
# Epoch 137/150
# 3/3 [==============================] - 1s 148ms/step - loss: 0.0095 - mae: 0.1072 - val_loss: 0.0396 - val_mae: 0.2376
# Epoch 138/150
# 3/3 [==============================] - 1s 190ms/step - loss: 0.0095 - mae: 0.1078 - val_loss: 0.0418 - val_mae: 0.2459
# Epoch 139/150
# 3/3 [==============================] - 1s 160ms/step - loss: 0.0095 - mae: 0.1076 - val_loss: 0.0415 - val_mae: 0.2451
# Epoch 140/150
# 3/3 [==============================] - 1s 141ms/step - loss: 0.0091 - mae: 0.1048 - val_loss: 0.0399 - val_mae: 0.2391
# Epoch 141/150
# 3/3 [==============================] - 1s 177ms/step - loss: 0.0093 - mae: 0.1058 - val_loss: 0.0450 - val_mae: 0.2571
# Epoch 142/150
# 3/3 [==============================] - 1s 142ms/step - loss: 0.0096 - mae: 0.1076 - val_loss: 0.0401 - val_mae: 0.2397
# Epoch 143/150
# 3/3 [==============================] - 1s 136ms/step - loss: 0.0092 - mae: 0.1054 - val_loss: 0.0407 - val_mae: 0.2422
# Epoch 144/150
# 3/3 [==============================] - 1s 182ms/step - loss: 0.0089 - mae: 0.1037 - val_loss: 0.0430 - val_mae: 0.2502
# Epoch 145/150
# 3/3 [==============================] - 1s 147ms/step - loss: 0.0090 - mae: 0.1036 - val_loss: 0.0415 - val_mae: 0.2448
# Epoch 146/150
# 3/3 [==============================] - 1s 139ms/step - loss: 0.0092 - mae: 0.1050 - val_loss: 0.0398 - val_mae: 0.2386
# Epoch 147/150
# 3/3 [==============================] - 1s 144ms/step - loss: 0.0092 - mae: 0.1051 - val_loss: 0.0408 - val_mae: 0.2421
# Epoch 148/150
# 3/3 [==============================] - 1s 141ms/step - loss: 0.0085 - mae: 0.1010 - val_loss: 0.0445 - val_mae: 0.2549
# Epoch 149/150
# 3/3 [==============================] - 1s 181ms/step - loss: 0.0098 - mae: 0.1085 - val_loss: 0.0401 - val_mae: 0.2397
# Epoch 150/150
# 3/3 [==============================] - 1s 135ms/step - loss: 0.0088 - mae: 0.1024 - val_loss: 0.0411 - val_mae: 0.2432
# Prediction lookback (n_steps): 720
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/150
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 4s 828ms/step - loss: 0.4996 - mae: 0.8763 - val_loss: 0.1168 - val_mae: 0.3779
# Epoch 2/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.1442 - mae: 0.4342 - val_loss: 0.1599 - val_mae: 0.4695
# Epoch 3/150
# 3/3 [==============================] - 2s 623ms/step - loss: 0.1309 - mae: 0.4217 - val_loss: 0.0948 - val_mae: 0.3740
# Epoch 4/150
# 3/3 [==============================] - 2s 678ms/step - loss: 0.0708 - mae: 0.3099 - val_loss: 0.0681 - val_mae: 0.3083
# Epoch 5/150
# 3/3 [==============================] - 2s 617ms/step - loss: 0.0453 - mae: 0.2360 - val_loss: 0.0466 - val_mae: 0.2535
# Epoch 6/150
# 3/3 [==============================] - 2s 612ms/step - loss: 0.0327 - mae: 0.2025 - val_loss: 0.0353 - val_mae: 0.2240
# Epoch 7/150
# 3/3 [==============================] - 2s 686ms/step - loss: 0.0244 - mae: 0.1753 - val_loss: 0.0400 - val_mae: 0.2323
# Epoch 8/150
# 3/3 [==============================] - 2s 635ms/step - loss: 0.0235 - mae: 0.1719 - val_loss: 0.0431 - val_mae: 0.2380
# Epoch 9/150
# 3/3 [==============================] - 2s 682ms/step - loss: 0.0222 - mae: 0.1680 - val_loss: 0.0395 - val_mae: 0.2306
# Epoch 10/150
# 3/3 [==============================] - 2s 629ms/step - loss: 0.0208 - mae: 0.1611 - val_loss: 0.0404 - val_mae: 0.2357
# Epoch 11/150
# 3/3 [==============================] - 2s 597ms/step - loss: 0.0195 - mae: 0.1562 - val_loss: 0.0416 - val_mae: 0.2370
# Epoch 12/150
# 3/3 [==============================] - 2s 608ms/step - loss: 0.0189 - mae: 0.1541 - val_loss: 0.0414 - val_mae: 0.2378
# Epoch 13/150
# 3/3 [==============================] - 2s 658ms/step - loss: 0.0185 - mae: 0.1520 - val_loss: 0.0403 - val_mae: 0.2380
# Epoch 14/150
# 3/3 [==============================] - 2s 650ms/step - loss: 0.0181 - mae: 0.1505 - val_loss: 0.0393 - val_mae: 0.2331
# Epoch 15/150
# 3/3 [==============================] - 2s 584ms/step - loss: 0.0175 - mae: 0.1475 - val_loss: 0.0391 - val_mae: 0.2306
# Epoch 16/150
# 3/3 [==============================] - 2s 603ms/step - loss: 0.0165 - mae: 0.1427 - val_loss: 0.0377 - val_mae: 0.2280
# Epoch 17/150
# 3/3 [==============================] - 2s 672ms/step - loss: 0.0169 - mae: 0.1449 - val_loss: 0.0385 - val_mae: 0.2297
# Epoch 18/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0161 - mae: 0.1405 - val_loss: 0.0390 - val_mae: 0.2315
# Epoch 19/150
# 3/3 [==============================] - 2s 604ms/step - loss: 0.0162 - mae: 0.1418 - val_loss: 0.0386 - val_mae: 0.2310
# Epoch 20/150
# 3/3 [==============================] - 2s 627ms/step - loss: 0.0159 - mae: 0.1400 - val_loss: 0.0391 - val_mae: 0.2315
# Epoch 21/150
# 3/3 [==============================] - 2s 599ms/step - loss: 0.0150 - mae: 0.1363 - val_loss: 0.0388 - val_mae: 0.2315
# Epoch 22/150
# 3/3 [==============================] - 2s 640ms/step - loss: 0.0150 - mae: 0.1358 - val_loss: 0.0394 - val_mae: 0.2325
# Epoch 23/150
# 3/3 [==============================] - 2s 666ms/step - loss: 0.0147 - mae: 0.1343 - val_loss: 0.0394 - val_mae: 0.2328
# Epoch 24/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0147 - mae: 0.1343 - val_loss: 0.0396 - val_mae: 0.2327
# Epoch 25/150
# 3/3 [==============================] - 2s 620ms/step - loss: 0.0142 - mae: 0.1307 - val_loss: 0.0394 - val_mae: 0.2322
# Epoch 26/150
# 3/3 [==============================] - 2s 663ms/step - loss: 0.0140 - mae: 0.1311 - val_loss: 0.0391 - val_mae: 0.2313
# Epoch 27/150
# 3/3 [==============================] - 2s 682ms/step - loss: 0.0137 - mae: 0.1291 - val_loss: 0.0390 - val_mae: 0.2311
# Epoch 28/150
# 3/3 [==============================] - 2s 663ms/step - loss: 0.0138 - mae: 0.1302 - val_loss: 0.0393 - val_mae: 0.2317
# Epoch 29/150
# 3/3 [==============================] - 2s 609ms/step - loss: 0.0137 - mae: 0.1293 - val_loss: 0.0393 - val_mae: 0.2320
# Epoch 30/150
# 3/3 [==============================] - 2s 654ms/step - loss: 0.0133 - mae: 0.1276 - val_loss: 0.0392 - val_mae: 0.2324
# Epoch 31/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0136 - mae: 0.1291 - val_loss: 0.0400 - val_mae: 0.2339
# Epoch 32/150
# 3/3 [==============================] - 2s 611ms/step - loss: 0.0129 - mae: 0.1256 - val_loss: 0.0397 - val_mae: 0.2334
# Epoch 33/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0129 - mae: 0.1254 - val_loss: 0.0399 - val_mae: 0.2330
# Epoch 34/150
# 3/3 [==============================] - 2s 662ms/step - loss: 0.0125 - mae: 0.1236 - val_loss: 0.0395 - val_mae: 0.2319
# Epoch 35/150
# 3/3 [==============================] - 2s 636ms/step - loss: 0.0126 - mae: 0.1235 - val_loss: 0.0392 - val_mae: 0.2320
# Epoch 36/150
# 3/3 [==============================] - 2s 611ms/step - loss: 0.0126 - mae: 0.1234 - val_loss: 0.0402 - val_mae: 0.2336
# Epoch 37/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0124 - mae: 0.1225 - val_loss: 0.0399 - val_mae: 0.2330
# Epoch 38/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0121 - mae: 0.1213 - val_loss: 0.0396 - val_mae: 0.2324
# Epoch 39/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0119 - mae: 0.1205 - val_loss: 0.0395 - val_mae: 0.2322
# Epoch 40/150
# 3/3 [==============================] - 2s 663ms/step - loss: 0.0119 - mae: 0.1201 - val_loss: 0.0397 - val_mae: 0.2325
# Epoch 41/150
# 3/3 [==============================] - 2s 598ms/step - loss: 0.0119 - mae: 0.1206 - val_loss: 0.0396 - val_mae: 0.2317
# Epoch 42/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0117 - mae: 0.1192 - val_loss: 0.0394 - val_mae: 0.2317
# Epoch 43/150
# 3/3 [==============================] - 2s 675ms/step - loss: 0.0111 - mae: 0.1158 - val_loss: 0.0392 - val_mae: 0.2314
# Epoch 44/150
# 3/3 [==============================] - 2s 622ms/step - loss: 0.0112 - mae: 0.1164 - val_loss: 0.0395 - val_mae: 0.2324
# Epoch 45/150
# 3/3 [==============================] - 2s 602ms/step - loss: 0.0108 - mae: 0.1147 - val_loss: 0.0396 - val_mae: 0.2323
# Epoch 46/150
# 3/3 [==============================] - 2s 616ms/step - loss: 0.0111 - mae: 0.1157 - val_loss: 0.0392 - val_mae: 0.2312
# Epoch 47/150
# 3/3 [==============================] - 2s 629ms/step - loss: 0.0109 - mae: 0.1148 - val_loss: 0.0390 - val_mae: 0.2307
# Epoch 48/150
# 3/3 [==============================] - 2s 603ms/step - loss: 0.0107 - mae: 0.1139 - val_loss: 0.0393 - val_mae: 0.2313
# Epoch 49/150
# 3/3 [==============================] - 2s 632ms/step - loss: 0.0103 - mae: 0.1120 - val_loss: 0.0393 - val_mae: 0.2316
# Epoch 50/150
# 3/3 [==============================] - 2s 634ms/step - loss: 0.0109 - mae: 0.1147 - val_loss: 0.0392 - val_mae: 0.2322
# Epoch 51/150
# 3/3 [==============================] - 2s 655ms/step - loss: 0.0105 - mae: 0.1131 - val_loss: 0.0408 - val_mae: 0.2339
# Epoch 52/150
# 3/3 [==============================] - 2s 665ms/step - loss: 0.0107 - mae: 0.1137 - val_loss: 0.0387 - val_mae: 0.2315
# Epoch 53/150
# 3/3 [==============================] - 2s 665ms/step - loss: 0.0104 - mae: 0.1124 - val_loss: 0.0408 - val_mae: 0.2332
# Epoch 54/150
# 3/3 [==============================] - 2s 673ms/step - loss: 0.0102 - mae: 0.1100 - val_loss: 0.0392 - val_mae: 0.2323
# Epoch 55/150
# 3/3 [==============================] - 2s 602ms/step - loss: 0.0103 - mae: 0.1114 - val_loss: 0.0402 - val_mae: 0.2332
# Epoch 56/150
# 3/3 [==============================] - 2s 626ms/step - loss: 0.0096 - mae: 0.1078 - val_loss: 0.0394 - val_mae: 0.2328
# Epoch 57/150
# 3/3 [==============================] - 2s 640ms/step - loss: 0.0096 - mae: 0.1079 - val_loss: 0.0399 - val_mae: 0.2327
# Epoch 58/150
# 3/3 [==============================] - 2s 664ms/step - loss: 0.0095 - mae: 0.1065 - val_loss: 0.0396 - val_mae: 0.2317
# Epoch 59/150
# 3/3 [==============================] - 2s 657ms/step - loss: 0.0095 - mae: 0.1064 - val_loss: 0.0394 - val_mae: 0.2315
# Epoch 60/150
# 3/3 [==============================] - 2s 599ms/step - loss: 0.0094 - mae: 0.1062 - val_loss: 0.0400 - val_mae: 0.2332
# Epoch 61/150
# 3/3 [==============================] - 2s 704ms/step - loss: 0.0087 - mae: 0.1027 - val_loss: 0.0397 - val_mae: 0.2331
# Epoch 62/150
# 3/3 [==============================] - 2s 676ms/step - loss: 0.0090 - mae: 0.1040 - val_loss: 0.0400 - val_mae: 0.2331
# Epoch 63/150
# 3/3 [==============================] - 2s 620ms/step - loss: 0.0089 - mae: 0.1032 - val_loss: 0.0399 - val_mae: 0.2329
# Epoch 64/150
# 3/3 [==============================] - 2s 606ms/step - loss: 0.0089 - mae: 0.1035 - val_loss: 0.0403 - val_mae: 0.2330
# Epoch 65/150
# 3/3 [==============================] - 2s 615ms/step - loss: 0.0086 - mae: 0.1024 - val_loss: 0.0392 - val_mae: 0.2331
# Epoch 66/150
# 3/3 [==============================] - 2s 670ms/step - loss: 0.0087 - mae: 0.1029 - val_loss: 0.0405 - val_mae: 0.2339
# Epoch 67/150
# 3/3 [==============================] - 2s 615ms/step - loss: 0.0085 - mae: 0.1008 - val_loss: 0.0401 - val_mae: 0.2346
# Epoch 68/150
# 3/3 [==============================] - 2s 648ms/step - loss: 0.0086 - mae: 0.1014 - val_loss: 0.0404 - val_mae: 0.2347
# Epoch 69/150
# 3/3 [==============================] - 2s 665ms/step - loss: 0.0086 - mae: 0.1019 - val_loss: 0.0402 - val_mae: 0.2340
# Epoch 70/150
# 3/3 [==============================] - 2s 607ms/step - loss: 0.0086 - mae: 0.1018 - val_loss: 0.0405 - val_mae: 0.2341
# Epoch 71/150
# 3/3 [==============================] - 2s 592ms/step - loss: 0.0084 - mae: 0.0999 - val_loss: 0.0396 - val_mae: 0.2339
# Epoch 72/150
# 3/3 [==============================] - 2s 618ms/step - loss: 0.0080 - mae: 0.0986 - val_loss: 0.0403 - val_mae: 0.2341
# Epoch 73/150
# 3/3 [==============================] - 2s 655ms/step - loss: 0.0079 - mae: 0.0979 - val_loss: 0.0401 - val_mae: 0.2350
# Epoch 74/150
# 3/3 [==============================] - 2s 618ms/step - loss: 0.0079 - mae: 0.0978 - val_loss: 0.0402 - val_mae: 0.2344
# Epoch 75/150
# 3/3 [==============================] - 2s 664ms/step - loss: 0.0077 - mae: 0.0957 - val_loss: 0.0394 - val_mae: 0.2341
# Epoch 76/150
# 3/3 [==============================] - 2s 604ms/step - loss: 0.0078 - mae: 0.0972 - val_loss: 0.0406 - val_mae: 0.2348
# Epoch 77/150
# 3/3 [==============================] - 2s 604ms/step - loss: 0.0079 - mae: 0.0978 - val_loss: 0.0397 - val_mae: 0.2340
# Epoch 78/150
# 3/3 [==============================] - 2s 601ms/step - loss: 0.0080 - mae: 0.0974 - val_loss: 0.0401 - val_mae: 0.2353
# Epoch 79/150
# 3/3 [==============================] - 2s 678ms/step - loss: 0.0080 - mae: 0.0978 - val_loss: 0.0411 - val_mae: 0.2360
# Epoch 80/150
# 3/3 [==============================] - 2s 608ms/step - loss: 0.0079 - mae: 0.0976 - val_loss: 0.0398 - val_mae: 0.2345
# Epoch 81/150
# 3/3 [==============================] - 2s 599ms/step - loss: 0.0076 - mae: 0.0955 - val_loss: 0.0396 - val_mae: 0.2340
# Epoch 82/150
# 3/3 [==============================] - 2s 611ms/step - loss: 0.0078 - mae: 0.0978 - val_loss: 0.0412 - val_mae: 0.2364
# Epoch 83/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0073 - mae: 0.0936 - val_loss: 0.0409 - val_mae: 0.2372
# Epoch 84/150
# 3/3 [==============================] - 2s 603ms/step - loss: 0.0073 - mae: 0.0934 - val_loss: 0.0404 - val_mae: 0.2353
# Epoch 85/150
# 3/3 [==============================] - 2s 602ms/step - loss: 0.0075 - mae: 0.0951 - val_loss: 0.0399 - val_mae: 0.2353
# Epoch 86/150
# 3/3 [==============================] - 2s 641ms/step - loss: 0.0074 - mae: 0.0938 - val_loss: 0.0404 - val_mae: 0.2343
# Epoch 87/150
# 3/3 [==============================] - 2s 668ms/step - loss: 0.0076 - mae: 0.0953 - val_loss: 0.0396 - val_mae: 0.2341
# Epoch 88/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0072 - mae: 0.0926 - val_loss: 0.0401 - val_mae: 0.2340
# Epoch 89/150
# 3/3 [==============================] - 2s 634ms/step - loss: 0.0071 - mae: 0.0918 - val_loss: 0.0398 - val_mae: 0.2351
# Epoch 90/150
# 3/3 [==============================] - 2s 611ms/step - loss: 0.0069 - mae: 0.0911 - val_loss: 0.0405 - val_mae: 0.2354
# Epoch 91/150
# 3/3 [==============================] - 2s 591ms/step - loss: 0.0069 - mae: 0.0907 - val_loss: 0.0406 - val_mae: 0.2351
# Epoch 92/150
# 3/3 [==============================] - 2s 624ms/step - loss: 0.0071 - mae: 0.0920 - val_loss: 0.0397 - val_mae: 0.2353
# Epoch 93/150
# 3/3 [==============================] - 2s 687ms/step - loss: 0.0072 - mae: 0.0924 - val_loss: 0.0405 - val_mae: 0.2347
# Epoch 94/150
# 3/3 [==============================] - 2s 633ms/step - loss: 0.0070 - mae: 0.0908 - val_loss: 0.0402 - val_mae: 0.2366
# Epoch 95/150
# 3/3 [==============================] - 2s 641ms/step - loss: 0.0069 - mae: 0.0916 - val_loss: 0.0409 - val_mae: 0.2359
# Epoch 96/150
# 3/3 [==============================] - 2s 606ms/step - loss: 0.0067 - mae: 0.0898 - val_loss: 0.0398 - val_mae: 0.2352
# Epoch 97/150
# 3/3 [==============================] - 2s 597ms/step - loss: 0.0069 - mae: 0.0905 - val_loss: 0.0405 - val_mae: 0.2347
# Epoch 98/150
# 3/3 [==============================] - 2s 630ms/step - loss: 0.0068 - mae: 0.0905 - val_loss: 0.0404 - val_mae: 0.2354
# Epoch 99/150
# 3/3 [==============================] - 2s 654ms/step - loss: 0.0066 - mae: 0.0884 - val_loss: 0.0402 - val_mae: 0.2347
# Epoch 100/150
# 3/3 [==============================] - 2s 612ms/step - loss: 0.0064 - mae: 0.0879 - val_loss: 0.0400 - val_mae: 0.2349
# Epoch 101/150
# 3/3 [==============================] - 2s 607ms/step - loss: 0.0066 - mae: 0.0881 - val_loss: 0.0405 - val_mae: 0.2356
# Epoch 102/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0064 - mae: 0.0884 - val_loss: 0.0404 - val_mae: 0.2355
# Epoch 103/150
# 3/3 [==============================] - 2s 642ms/step - loss: 0.0064 - mae: 0.0878 - val_loss: 0.0393 - val_mae: 0.2335
# Epoch 104/150
# 3/3 [==============================] - 2s 620ms/step - loss: 0.0065 - mae: 0.0871 - val_loss: 0.0400 - val_mae: 0.2344
# Epoch 105/150
# 3/3 [==============================] - 2s 626ms/step - loss: 0.0061 - mae: 0.0860 - val_loss: 0.0405 - val_mae: 0.2367
# Epoch 106/150
# 3/3 [==============================] - 2s 669ms/step - loss: 0.0064 - mae: 0.0874 - val_loss: 0.0403 - val_mae: 0.2354
# Epoch 107/150
# 3/3 [==============================] - 2s 643ms/step - loss: 0.0063 - mae: 0.0867 - val_loss: 0.0405 - val_mae: 0.2357
# Epoch 108/150
# 3/3 [==============================] - 2s 608ms/step - loss: 0.0067 - mae: 0.0895 - val_loss: 0.0406 - val_mae: 0.2367
# Epoch 109/150
# 3/3 [==============================] - 2s 643ms/step - loss: 0.0063 - mae: 0.0868 - val_loss: 0.0408 - val_mae: 0.2360
# Epoch 110/150
# 3/3 [==============================] - 2s 688ms/step - loss: 0.0063 - mae: 0.0862 - val_loss: 0.0395 - val_mae: 0.2338
# Epoch 111/150
# 3/3 [==============================] - 2s 618ms/step - loss: 0.0064 - mae: 0.0874 - val_loss: 0.0398 - val_mae: 0.2337
# Epoch 112/150
# 3/3 [==============================] - 2s 602ms/step - loss: 0.0061 - mae: 0.0848 - val_loss: 0.0402 - val_mae: 0.2352
# Epoch 113/150
# 3/3 [==============================] - 2s 625ms/step - loss: 0.0063 - mae: 0.0862 - val_loss: 0.0405 - val_mae: 0.2360
# Epoch 114/150
# 3/3 [==============================] - 2s 623ms/step - loss: 0.0060 - mae: 0.0841 - val_loss: 0.0406 - val_mae: 0.2364
# Epoch 115/150
# 3/3 [==============================] - 2s 607ms/step - loss: 0.0061 - mae: 0.0858 - val_loss: 0.0404 - val_mae: 0.2351
# Epoch 116/150
# 3/3 [==============================] - 2s 602ms/step - loss: 0.0059 - mae: 0.0837 - val_loss: 0.0402 - val_mae: 0.2351
# Epoch 117/150
# 3/3 [==============================] - 2s 634ms/step - loss: 0.0059 - mae: 0.0842 - val_loss: 0.0404 - val_mae: 0.2358
# Epoch 118/150
# 3/3 [==============================] - 2s 672ms/step - loss: 0.0060 - mae: 0.0842 - val_loss: 0.0405 - val_mae: 0.2353
# Epoch 119/150
# 3/3 [==============================] - 2s 621ms/step - loss: 0.0057 - mae: 0.0826 - val_loss: 0.0400 - val_mae: 0.2342
# Epoch 120/150
# 3/3 [==============================] - 2s 667ms/step - loss: 0.0059 - mae: 0.0834 - val_loss: 0.0408 - val_mae: 0.2358
# Epoch 121/150
# 3/3 [==============================] - 2s 686ms/step - loss: 0.0058 - mae: 0.0834 - val_loss: 0.0407 - val_mae: 0.2381
# Epoch 122/150
# 3/3 [==============================] - 2s 633ms/step - loss: 0.0059 - mae: 0.0838 - val_loss: 0.0412 - val_mae: 0.2370
# Epoch 123/150
# 3/3 [==============================] - 2s 631ms/step - loss: 0.0065 - mae: 0.0874 - val_loss: 0.0408 - val_mae: 0.2362
# Epoch 124/150
# 3/3 [==============================] - 2s 694ms/step - loss: 0.0058 - mae: 0.0824 - val_loss: 0.0402 - val_mae: 0.2363
# Epoch 125/150
# 3/3 [==============================] - 2s 712ms/step - loss: 0.0062 - mae: 0.0861 - val_loss: 0.0421 - val_mae: 0.2383
# Epoch 126/150
# 3/3 [==============================] - 2s 657ms/step - loss: 0.0060 - mae: 0.0842 - val_loss: 0.0410 - val_mae: 0.2394
# Epoch 127/150
# 3/3 [==============================] - 2s 659ms/step - loss: 0.0060 - mae: 0.0851 - val_loss: 0.0424 - val_mae: 0.2386
# Epoch 128/150
# 3/3 [==============================] - 2s 627ms/step - loss: 0.0061 - mae: 0.0861 - val_loss: 0.0404 - val_mae: 0.2366
# Epoch 129/150
# 3/3 [==============================] - 2s 609ms/step - loss: 0.0058 - mae: 0.0834 - val_loss: 0.0410 - val_mae: 0.2371
# Epoch 130/150
# 3/3 [==============================] - 2s 656ms/step - loss: 0.0057 - mae: 0.0830 - val_loss: 0.0404 - val_mae: 0.2357
# Epoch 131/150
# 3/3 [==============================] - 2s 617ms/step - loss: 0.0055 - mae: 0.0819 - val_loss: 0.0404 - val_mae: 0.2364
# Epoch 132/150
# 3/3 [==============================] - 2s 646ms/step - loss: 0.0057 - mae: 0.0826 - val_loss: 0.0418 - val_mae: 0.2383
# Epoch 133/150
# 3/3 [==============================] - 2s 615ms/step - loss: 0.0057 - mae: 0.0820 - val_loss: 0.0406 - val_mae: 0.2372
# Epoch 134/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0055 - mae: 0.0815 - val_loss: 0.0415 - val_mae: 0.2370
# Epoch 135/150
# 3/3 [==============================] - 2s 636ms/step - loss: 0.0055 - mae: 0.0806 - val_loss: 0.0402 - val_mae: 0.2349
# Epoch 136/150
# 3/3 [==============================] - 2s 677ms/step - loss: 0.0054 - mae: 0.0799 - val_loss: 0.0402 - val_mae: 0.2349
# Epoch 137/150
# 3/3 [==============================] - 2s 614ms/step - loss: 0.0053 - mae: 0.0785 - val_loss: 0.0412 - val_mae: 0.2373
# Epoch 138/150
# 3/3 [==============================] - 2s 615ms/step - loss: 0.0052 - mae: 0.0788 - val_loss: 0.0416 - val_mae: 0.2385
# Epoch 139/150
# 3/3 [==============================] - 2s 605ms/step - loss: 0.0052 - mae: 0.0781 - val_loss: 0.0408 - val_mae: 0.2371
# Epoch 140/150
# 3/3 [==============================] - 2s 610ms/step - loss: 0.0050 - mae: 0.0779 - val_loss: 0.0403 - val_mae: 0.2356
# Epoch 141/150
# 3/3 [==============================] - 2s 605ms/step - loss: 0.0051 - mae: 0.0778 - val_loss: 0.0411 - val_mae: 0.2370
# Epoch 142/150
# 3/3 [==============================] - 2s 612ms/step - loss: 0.0050 - mae: 0.0777 - val_loss: 0.0412 - val_mae: 0.2377
# Epoch 143/150
# 3/3 [==============================] - 2s 611ms/step - loss: 0.0051 - mae: 0.0783 - val_loss: 0.0406 - val_mae: 0.2369
# Epoch 144/150
# 3/3 [==============================] - 2s 606ms/step - loss: 0.0051 - mae: 0.0779 - val_loss: 0.0403 - val_mae: 0.2357
# Epoch 145/150
# 3/3 [==============================] - 2s 681ms/step - loss: 0.0049 - mae: 0.0766 - val_loss: 0.0408 - val_mae: 0.2366
# Epoch 146/150
# 3/3 [==============================] - 2s 625ms/step - loss: 0.0052 - mae: 0.0788 - val_loss: 0.0409 - val_mae: 0.2375
# Epoch 147/150
# 3/3 [==============================] - 2s 635ms/step - loss: 0.0048 - mae: 0.0765 - val_loss: 0.0413 - val_mae: 0.2376
# Epoch 148/150
# 3/3 [==============================] - 2s 617ms/step - loss: 0.0050 - mae: 0.0775 - val_loss: 0.0402 - val_mae: 0.2370
# Epoch 149/150
# 3/3 [==============================] - 2s 650ms/step - loss: 0.0051 - mae: 0.0783 - val_loss: 0.0413 - val_mae: 0.2379
# Epoch 150/150
# 3/3 [==============================] - 2s 629ms/step - loss: 0.0051 - mae: 0.0782 - val_loss: 0.0404 - val_mae: 0.2379
# Prediction lookback (n_steps): 720
# Prediction horizon (n_horizon): 24
# Batch Size: 256
# Datasets:
# (TensorSpec(shape=(None, None, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))
# Epoch 1/150
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 3/3 [==============================] - 15s 4s/step - loss: 0.1196 - mae: 0.4498 - val_loss: 0.1271 - val_mae: 0.4608
# Epoch 2/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.1107 - mae: 0.4294 - val_loss: 0.1184 - val_mae: 0.4402
# Epoch 3/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0998 - mae: 0.4021 - val_loss: 0.1059 - val_mae: 0.4071
# Epoch 4/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0846 - mae: 0.3597 - val_loss: 0.0862 - val_mae: 0.3509
# Epoch 5/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0655 - mae: 0.2989 - val_loss: 0.0617 - val_mae: 0.2822
# Epoch 6/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0561 - mae: 0.2674 - val_loss: 0.0539 - val_mae: 0.2620
# Epoch 7/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0418 - mae: 0.2316 - val_loss: 0.0523 - val_mae: 0.2586
# Epoch 8/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0337 - mae: 0.2084 - val_loss: 0.0474 - val_mae: 0.2466
# Epoch 9/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0274 - mae: 0.1870 - val_loss: 0.0414 - val_mae: 0.2338
# Epoch 10/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0250 - mae: 0.1779 - val_loss: 0.0419 - val_mae: 0.2346
# Epoch 11/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0216 - mae: 0.1659 - val_loss: 0.0444 - val_mae: 0.2401
# Epoch 12/150
# 3/3 [==============================] - 12s 4s/step - loss: 0.0207 - mae: 0.1619 - val_loss: 0.0436 - val_mae: 0.2385
# Epoch 13/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0186 - mae: 0.1531 - val_loss: 0.0408 - val_mae: 0.2322
# Epoch 14/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0175 - mae: 0.1487 - val_loss: 0.0406 - val_mae: 0.2321
# Epoch 15/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0170 - mae: 0.1462 - val_loss: 0.0411 - val_mae: 0.2330
# Epoch 16/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0158 - mae: 0.1407 - val_loss: 0.0396 - val_mae: 0.2298
# Epoch 17/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0152 - mae: 0.1372 - val_loss: 0.0389 - val_mae: 0.2285
# Epoch 18/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0145 - mae: 0.1339 - val_loss: 0.0389 - val_mae: 0.2284
# Epoch 19/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0141 - mae: 0.1323 - val_loss: 0.0390 - val_mae: 0.2289
# Epoch 20/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0148 - mae: 0.1361 - val_loss: 0.0392 - val_mae: 0.2293
# Epoch 21/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0136 - mae: 0.1294 - val_loss: 0.0390 - val_mae: 0.2292
# Epoch 22/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0138 - mae: 0.1311 - val_loss: 0.0393 - val_mae: 0.2296
# Epoch 23/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0134 - mae: 0.1292 - val_loss: 0.0393 - val_mae: 0.2297
# Epoch 24/150
# 3/3 [==============================] - 13s 5s/step - loss: 0.0129 - mae: 0.1262 - val_loss: 0.0398 - val_mae: 0.2307
# Epoch 25/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0132 - mae: 0.1276 - val_loss: 0.0398 - val_mae: 0.2308
# Epoch 26/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0123 - mae: 0.1230 - val_loss: 0.0394 - val_mae: 0.2303
# Epoch 27/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0122 - mae: 0.1224 - val_loss: 0.0392 - val_mae: 0.2303
# Epoch 28/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0117 - mae: 0.1202 - val_loss: 0.0392 - val_mae: 0.2303
# Epoch 29/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0120 - mae: 0.1210 - val_loss: 0.0393 - val_mae: 0.2305
# Epoch 30/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0119 - mae: 0.1216 - val_loss: 0.0390 - val_mae: 0.2301
# Epoch 31/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0122 - mae: 0.1215 - val_loss: 0.0385 - val_mae: 0.2293
# Epoch 32/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0117 - mae: 0.1198 - val_loss: 0.0389 - val_mae: 0.2296
# Epoch 33/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0117 - mae: 0.1203 - val_loss: 0.0389 - val_mae: 0.2295
# Epoch 34/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0113 - mae: 0.1178 - val_loss: 0.0385 - val_mae: 0.2290
# Epoch 35/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0110 - mae: 0.1157 - val_loss: 0.0385 - val_mae: 0.2290
# Epoch 36/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0109 - mae: 0.1143 - val_loss: 0.0384 - val_mae: 0.2291
# Epoch 37/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0106 - mae: 0.1126 - val_loss: 0.0386 - val_mae: 0.2295
# Epoch 38/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0106 - mae: 0.1132 - val_loss: 0.0390 - val_mae: 0.2302
# Epoch 39/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0106 - mae: 0.1133 - val_loss: 0.0387 - val_mae: 0.2301
# Epoch 40/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0105 - mae: 0.1123 - val_loss: 0.0384 - val_mae: 0.2301
# Epoch 41/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0102 - mae: 0.1107 - val_loss: 0.0385 - val_mae: 0.2302
# Epoch 42/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0102 - mae: 0.1106 - val_loss: 0.0388 - val_mae: 0.2305
# Epoch 43/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0102 - mae: 0.1111 - val_loss: 0.0387 - val_mae: 0.2304
# Epoch 44/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0098 - mae: 0.1095 - val_loss: 0.0384 - val_mae: 0.2301
# Epoch 45/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0096 - mae: 0.1079 - val_loss: 0.0383 - val_mae: 0.2302
# Epoch 46/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0100 - mae: 0.1105 - val_loss: 0.0386 - val_mae: 0.2303
# Epoch 47/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0099 - mae: 0.1094 - val_loss: 0.0385 - val_mae: 0.2301
# Epoch 48/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0103 - mae: 0.1116 - val_loss: 0.0383 - val_mae: 0.2300
# Epoch 49/150
# 3/3 [==============================] - 10s 4s/step - loss: 0.0096 - mae: 0.1071 - val_loss: 0.0383 - val_mae: 0.2299
# Epoch 50/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0097 - mae: 0.1084 - val_loss: 0.0384 - val_mae: 0.2300
# Epoch 51/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0101 - mae: 0.1095 - val_loss: 0.0385 - val_mae: 0.2302
# Epoch 52/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0095 - mae: 0.1076 - val_loss: 0.0385 - val_mae: 0.2304
# Epoch 53/150
# 3/3 [==============================] - 10s 3s/step - loss: 0.0095 - mae: 0.1077 - val_loss: 0.0385 - val_mae: 0.2306
# Epoch 54/150
# 3/3 [==============================] - 11s 4s/step - loss: 0.0094 - mae: 0.1052 - val_loss: 0.0384 - val_mae: 0.2306
# Epoch 55/150
# ...
# Epoch 29/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0338 - mae: 0.2058 - val_loss: 0.0386 - val_mae: 0.2294
# Epoch 30/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0331 - mae: 0.2034 - val_loss: 0.0383 - val_mae: 0.2275
# Epoch 31/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0326 - mae: 0.2007 - val_loss: 0.0376 - val_mae: 0.2263
# Epoch 32/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0314 - mae: 0.1978 - val_loss: 0.0402 - val_mae: 0.2328
# Epoch 33/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0315 - mae: 0.1968 - val_loss: 0.0374 - val_mae: 0.2256
# Epoch 34/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0301 - mae: 0.1934 - val_loss: 0.0362 - val_mae: 0.2219
# Epoch 35/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0281 - mae: 0.1865 - val_loss: 0.0380 - val_mae: 0.2265
# Epoch 36/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0292 - mae: 0.1897 - val_loss: 0.0392 - val_mae: 0.2298
# Epoch 37/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0282 - mae: 0.1864 - val_loss: 0.0363 - val_mae: 0.2220
# Epoch 38/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0292 - mae: 0.1893 - val_loss: 0.0360 - val_mae: 0.2221
# Epoch 39/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0275 - mae: 0.1850 - val_loss: 0.0385 - val_mae: 0.2275
# Epoch 40/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0276 - mae: 0.1853 - val_loss: 0.0366 - val_mae: 0.2229
# Epoch 41/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0271 - mae: 0.1824 - val_loss: 0.0347 - val_mae: 0.2175
# Epoch 42/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0264 - mae: 0.1801 - val_loss: 0.0371 - val_mae: 0.2239
# Epoch 43/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0272 - mae: 0.1825 - val_loss: 0.0391 - val_mae: 0.2310
# Epoch 44/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0269 - mae: 0.1808 - val_loss: 0.0360 - val_mae: 0.2208
# Epoch 45/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0256 - mae: 0.1771 - val_loss: 0.0352 - val_mae: 0.2194
# Epoch 46/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0262 - mae: 0.1788 - val_loss: 0.0409 - val_mae: 0.2327
# Epoch 47/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0286 - mae: 0.1900 - val_loss: 0.0388 - val_mae: 0.2328
# Epoch 48/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0265 - mae: 0.1801 - val_loss: 0.0386 - val_mae: 0.2268
# Epoch 49/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0255 - mae: 0.1772 - val_loss: 0.0368 - val_mae: 0.2248
# Epoch 50/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0256 - mae: 0.1777 - val_loss: 0.0372 - val_mae: 0.2239
# Epoch 51/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0261 - mae: 0.1785 - val_loss: 0.0368 - val_mae: 0.2227
# Epoch 52/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0265 - mae: 0.1801 - val_loss: 0.0364 - val_mae: 0.2233
# Epoch 53/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0242 - mae: 0.1722 - val_loss: 0.0368 - val_mae: 0.2234
# Epoch 54/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0243 - mae: 0.1728 - val_loss: 0.0374 - val_mae: 0.2263
# Epoch 55/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0243 - mae: 0.1733 - val_loss: 0.0365 - val_mae: 0.2225
# Epoch 56/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0226 - mae: 0.1667 - val_loss: 0.0354 - val_mae: 0.2196
# Epoch 57/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0223 - mae: 0.1647 - val_loss: 0.0365 - val_mae: 0.2226
# Epoch 58/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0223 - mae: 0.1653 - val_loss: 0.0363 - val_mae: 0.2235
# Epoch 59/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0223 - mae: 0.1647 - val_loss: 0.0372 - val_mae: 0.2236
# Epoch 60/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0218 - mae: 0.1620 - val_loss: 0.0374 - val_mae: 0.2293
# Epoch 61/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0225 - mae: 0.1644 - val_loss: 0.0372 - val_mae: 0.2235
# Epoch 62/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0220 - mae: 0.1615 - val_loss: 0.0362 - val_mae: 0.2248
# Epoch 63/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0208 - mae: 0.1593 - val_loss: 0.0369 - val_mae: 0.2229
# Epoch 64/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0231 - mae: 0.1678 - val_loss: 0.0358 - val_mae: 0.2225
# Epoch 65/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0224 - mae: 0.1636 - val_loss: 0.0353 - val_mae: 0.2212
# Epoch 66/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0211 - mae: 0.1607 - val_loss: 0.0366 - val_mae: 0.2226
# Epoch 67/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0211 - mae: 0.1597 - val_loss: 0.0371 - val_mae: 0.2273
# Epoch 68/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0205 - mae: 0.1576 - val_loss: 0.0360 - val_mae: 0.2215
# Epoch 69/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0212 - mae: 0.1598 - val_loss: 0.0367 - val_mae: 0.2266
# Epoch 70/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0202 - mae: 0.1576 - val_loss: 0.0375 - val_mae: 0.2250
# Epoch 71/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0209 - mae: 0.1585 - val_loss: 0.0378 - val_mae: 0.2299
# Epoch 72/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0188 - mae: 0.1514 - val_loss: 0.0367 - val_mae: 0.2232
# Epoch 73/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0188 - mae: 0.1496 - val_loss: 0.0374 - val_mae: 0.2297
# Epoch 74/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0206 - mae: 0.1571 - val_loss: 0.0365 - val_mae: 0.2241
# Epoch 75/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0189 - mae: 0.1504 - val_loss: 0.0374 - val_mae: 0.2290
# Epoch 76/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0194 - mae: 0.1531 - val_loss: 0.0362 - val_mae: 0.2224
# Epoch 77/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0186 - mae: 0.1499 - val_loss: 0.0368 - val_mae: 0.2259
# Epoch 78/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0187 - mae: 0.1494 - val_loss: 0.0371 - val_mae: 0.2284
# Epoch 79/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0188 - mae: 0.1492 - val_loss: 0.0363 - val_mae: 0.2234
# Epoch 80/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0188 - mae: 0.1496 - val_loss: 0.0364 - val_mae: 0.2245
# Epoch 81/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0176 - mae: 0.1440 - val_loss: 0.0379 - val_mae: 0.2303
# Epoch 82/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0184 - mae: 0.1484 - val_loss: 0.0374 - val_mae: 0.2249
# Epoch 83/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0200 - mae: 0.1553 - val_loss: 0.0388 - val_mae: 0.2345
# Epoch 84/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0171 - mae: 0.1439 - val_loss: 0.0373 - val_mae: 0.2258
# Epoch 85/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0183 - mae: 0.1475 - val_loss: 0.0376 - val_mae: 0.2302
# Epoch 86/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0180 - mae: 0.1473 - val_loss: 0.0359 - val_mae: 0.2227
# Epoch 87/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0197 - mae: 0.1541 - val_loss: 0.0379 - val_mae: 0.2315
# Epoch 88/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0176 - mae: 0.1450 - val_loss: 0.0372 - val_mae: 0.2270
# Epoch 89/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0177 - mae: 0.1461 - val_loss: 0.0366 - val_mae: 0.2270
# Epoch 90/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0171 - mae: 0.1432 - val_loss: 0.0361 - val_mae: 0.2242
# Epoch 91/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0178 - mae: 0.1451 - val_loss: 0.0369 - val_mae: 0.2269
# Epoch 92/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0168 - mae: 0.1420 - val_loss: 0.0371 - val_mae: 0.2285
# Epoch 93/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0173 - mae: 0.1436 - val_loss: 0.0368 - val_mae: 0.2240
# Epoch 94/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0176 - mae: 0.1431 - val_loss: 0.0425 - val_mae: 0.2476
# Epoch 95/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0196 - mae: 0.1532 - val_loss: 0.0384 - val_mae: 0.2269
# Epoch 96/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0178 - mae: 0.1463 - val_loss: 0.0409 - val_mae: 0.2419
# Epoch 97/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0168 - mae: 0.1420 - val_loss: 0.0376 - val_mae: 0.2259
# Epoch 98/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0175 - mae: 0.1441 - val_loss: 0.0394 - val_mae: 0.2361
# Epoch 99/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0170 - mae: 0.1434 - val_loss: 0.0365 - val_mae: 0.2245
# Epoch 100/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0161 - mae: 0.1386 - val_loss: 0.0377 - val_mae: 0.2317
# Epoch 101/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0159 - mae: 0.1377 - val_loss: 0.0360 - val_mae: 0.2246
# Epoch 102/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0155 - mae: 0.1355 - val_loss: 0.0380 - val_mae: 0.2311
# Epoch 103/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0171 - mae: 0.1427 - val_loss: 0.0378 - val_mae: 0.2292
# Epoch 104/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0151 - mae: 0.1336 - val_loss: 0.0372 - val_mae: 0.2288
# Epoch 105/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0143 - mae: 0.1300 - val_loss: 0.0364 - val_mae: 0.2268
# Epoch 106/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0155 - mae: 0.1347 - val_loss: 0.0374 - val_mae: 0.2300
# Epoch 107/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0151 - mae: 0.1332 - val_loss: 0.0384 - val_mae: 0.2332
# Epoch 108/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0160 - mae: 0.1370 - val_loss: 0.0375 - val_mae: 0.2273
# Epoch 109/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0164 - mae: 0.1386 - val_loss: 0.0401 - val_mae: 0.2396
# Epoch 110/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0152 - mae: 0.1347 - val_loss: 0.0366 - val_mae: 0.2251
# Epoch 111/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0168 - mae: 0.1409 - val_loss: 0.0385 - val_mae: 0.2342
# Epoch 112/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0162 - mae: 0.1384 - val_loss: 0.0363 - val_mae: 0.2253
# Epoch 113/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0148 - mae: 0.1324 - val_loss: 0.0375 - val_mae: 0.2298
# Epoch 114/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0144 - mae: 0.1316 - val_loss: 0.0382 - val_mae: 0.2326
# Epoch 115/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0160 - mae: 0.1373 - val_loss: 0.0367 - val_mae: 0.2268
# Epoch 116/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0154 - mae: 0.1338 - val_loss: 0.0372 - val_mae: 0.2303
# Epoch 117/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0149 - mae: 0.1337 - val_loss: 0.0367 - val_mae: 0.2277
# Epoch 118/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0141 - mae: 0.1299 - val_loss: 0.0386 - val_mae: 0.2340
# Epoch 119/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0148 - mae: 0.1321 - val_loss: 0.0370 - val_mae: 0.2262
# Epoch 120/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0153 - mae: 0.1346 - val_loss: 0.0386 - val_mae: 0.2341
# Epoch 121/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0136 - mae: 0.1265 - val_loss: 0.0376 - val_mae: 0.2298
# Epoch 122/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0140 - mae: 0.1284 - val_loss: 0.0372 - val_mae: 0.2281
# Epoch 123/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0151 - mae: 0.1332 - val_loss: 0.0372 - val_mae: 0.2291
# Epoch 124/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0147 - mae: 0.1312 - val_loss: 0.0369 - val_mae: 0.2284
# Epoch 125/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0141 - mae: 0.1280 - val_loss: 0.0365 - val_mae: 0.2269
# Epoch 126/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0140 - mae: 0.1288 - val_loss: 0.0370 - val_mae: 0.2286
# Epoch 127/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0148 - mae: 0.1308 - val_loss: 0.0371 - val_mae: 0.2270
# Epoch 128/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0152 - mae: 0.1330 - val_loss: 0.0387 - val_mae: 0.2347
# Epoch 129/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0133 - mae: 0.1266 - val_loss: 0.0365 - val_mae: 0.2265
# Epoch 130/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0138 - mae: 0.1275 - val_loss: 0.0376 - val_mae: 0.2314
# Epoch 131/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0125 - mae: 0.1208 - val_loss: 0.0359 - val_mae: 0.2246
# Epoch 132/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0141 - mae: 0.1298 - val_loss: 0.0367 - val_mae: 0.2278
# Epoch 133/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0141 - mae: 0.1283 - val_loss: 0.0374 - val_mae: 0.2293
# Epoch 134/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0134 - mae: 0.1262 - val_loss: 0.0379 - val_mae: 0.2318
# Epoch 135/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0133 - mae: 0.1241 - val_loss: 0.0370 - val_mae: 0.2277
# Epoch 136/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0137 - mae: 0.1272 - val_loss: 0.0371 - val_mae: 0.2289
# Epoch 137/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0133 - mae: 0.1248 - val_loss: 0.0357 - val_mae: 0.2247
# Epoch 138/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0130 - mae: 0.1244 - val_loss: 0.0370 - val_mae: 0.2293
# Epoch 139/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0133 - mae: 0.1252 - val_loss: 0.0374 - val_mae: 0.2295
# Epoch 140/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0117 - mae: 0.1177 - val_loss: 0.0375 - val_mae: 0.2297
# Epoch 141/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0118 - mae: 0.1185 - val_loss: 0.0369 - val_mae: 0.2282
# Epoch 142/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0131 - mae: 0.1240 - val_loss: 0.0372 - val_mae: 0.2300
# Epoch 143/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0121 - mae: 0.1180 - val_loss: 0.0364 - val_mae: 0.2263
# Epoch 144/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0132 - mae: 0.1248 - val_loss: 0.0383 - val_mae: 0.2336
# Epoch 145/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0133 - mae: 0.1251 - val_loss: 0.0369 - val_mae: 0.2269
# Epoch 146/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0121 - mae: 0.1187 - val_loss: 0.0389 - val_mae: 0.2342
# Epoch 147/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0129 - mae: 0.1243 - val_loss: 0.0369 - val_mae: 0.2268
# Epoch 148/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0126 - mae: 0.1211 - val_loss: 0.0375 - val_mae: 0.2301
# Epoch 149/150
# 3/3 [==============================] - 5s 2s/step - loss: 0.0120 - mae: 0.1195 - val_loss: 0.0366 - val_mae: 0.2262
# Epoch 150/150
# 3/3 [==============================] - 5s 1s/step - loss: 0.0127 - mae: 0.1229 - val_loss: 0.0383 - val_mae: 0.2333
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, None, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, None, 1), dtype=tf.float64, name=None))>

# %%
legend = list()

fig, axs = plt.subplots(1, 5, figsize=(25,5))

def plot_graphs(metric, val, ax, upper):
    ax.plot(val['history'].history[metric])
    ax.plot(val['history'].history[f'val_{metric}'])
    ax.set_title(key)
    ax.legend([metric, f"val_{metric}"])
    ax.set_xlabel('epochs')
    ax.set_ylabel(metric)
    ax.set_ylim([0, upper])
    
for (key, val), ax in zip(model_configs.items(), axs.flatten()):
    plot_graphs('loss', val, ax, 0.2)
print("Loss Curves")
# Out:
# Loss Curves

# %%
print("MAE Curves")
fig, axs = plt.subplots(1, 5, figsize=(25,5))
for (key, val), ax in zip(model_configs.items(), axs.flatten()):
    plot_graphs('mae', val, ax, 0.6)
# Out:
# MAE Curves

# %% [markdown]
# The LSTM and the CNN stacked LSTM models clearly outperformed the other four models. Whats surprising is to see how well both a CNN and DNN did on their. LSTM would be expected to perform well because of its ability to learn and remember longer trends in the data.
#
# Putting the models' performance in perspective however the results show how with a limited lookback window, and simple features a lstm, and a cnn stacked with an lstm are a good starting choice for architecture.

# %%
names = list()
performance = list()

for key, value in model_configs.items():
    names.append(key)
    mae = value['model'].evaluate(value['test_ds'])
    performance.append(mae[1])
    
performance_df = pd.DataFrame(performance, index=names, columns=['mae'])
performance_df['error_mw'] = performance_df['mae'] * df['total load forecast'].mean()
print(performance_df)
# Out:
# 2/2 [==============================] - 1s 119ms/step - loss: 0.0074 - mae: 0.0953
# 2/2 [==============================] - 1s 122ms/step - loss: 0.0064 - mae: 0.0815
# 2/2 [==============================] - 2s 500ms/step - loss: 0.0061 - mae: 0.0821
# 2/2 [==============================] - 1s 238ms/step - loss: 0.0064 - mae: 0.0831
# 2/2 [==============================] - 1s 191ms/step - loss: 0.0066 - mae: 0.0886
#                 mae     error_mw
# dnn        0.095250  2734.836884
# cnn        0.081462  2338.953187
# lstm       0.082074  2356.531375
# lstm_cnn   0.083127  2386.742729
# lstm_skip  0.088593  2543.688130

# %% [markdown]
# Visualizing Predictions: Plot the actual and predicted 24 hour intervals. Below is the first 14 days of predictions. Interesting to note how the LSTM appears to oscilate over a longer frequency compared with the other models. The CNN also seems to capture the intra day oscillations (within the 24 hour period). Looking at the CNN stacked LSTM we can see how these two characteristics of the model's learning combine.

# %%
fig, axs = plt.subplots(5, 1, figsize=(18, 10))
days = 14

vline = np.linspace(0, days*24, days+1)

for (key, val), ax in zip(model_configs.items(), axs):

    test = val['test_ds']
    preds = val['model'].predict(test)

    xbatch, ybatch = iter(test).get_next()

    ax.plot(ybatch.numpy()[:days].reshape(-1))
    ax.plot(preds[:days].reshape(-1))
    ax.set_title(key)
    ax.vlines(vline, ymin=0, ymax=1, linestyle='dotted', transform = ax.get_xaxis_transform())
    ax.legend(["Actual", "Predicted"])

plt.xlabel("Hours Cumulative")
print('First Two Weeks of Predictions')
# Out:
# 2/2 [==============================] - 1s 46ms/step
# 2/2 [==============================] - 1s 109ms/step
# 2/2 [==============================] - 3s 484ms/step
# 2/2 [==============================] - 1s 166ms/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f98f7539af0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 1s 172ms/step
# First Two Weeks of Predictions
